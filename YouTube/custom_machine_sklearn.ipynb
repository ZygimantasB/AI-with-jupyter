# %%
import numpy as np
from sklearn.base import BaseEstimator, ClassifierMixin, RegressorMixin
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
class NearestCentroidClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self):
        self.centroids_ = None
        self.classes_ = None

    def fit(self, X, y):
        self.classes_ = np.unique(y)
        self.centroids_ = np.zeros((len(self.classes_), X.shape[1]))

        for idx, cls in enumerate(self.classes_):
            self.centroids_[idx, :] = X[y == cls].mean(axis=0)

        return self

    def predict(self, X):
        distances = np.zeros((X.shape[0], len(self.classes_)))

        for idx, centroid in enumerate(self.classes_):
            distances[:, idx] = np.linalg.norm(X - self.centroids_, axis=1)

        return self.classes_[np.argmin(distances, axis=1)]

    def predict_proba(self, X):
        distances = np.zeros((X.shape[0], len(self.classes_)))

if __name__ == "__main__":
    data = load_iris()
    X, y = data.data, data.target

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

    # clf = AlwaysOneClassifier()

    # clf.fit(X, y)
    #
    # clf.fit(X_train, y_train)
    #
    # print(clf.score(X_test, y_test))
# Out:
# 0.3
